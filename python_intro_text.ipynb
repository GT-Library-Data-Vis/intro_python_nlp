# %%
# Welcome to Introduction to Python
# Raven Davis
# raven.davis@library.gatech.edu
# Jay Forrest
# jay.forrest@library.gatech.edu

# Resources
# GT Library: www.library.gatech.edu
# Anaconda Distribution: www.anaconda.com
# Datacamp:  www.datacamp.com
# LinkedIn Learning: linkedinlearning.gatech.edu


# Objectives
# Understand basics of programming in python, including creating variables,
# common data types, and common functions.
# Apply common functions for working with text data
# Load a text data set and utilize natural language processing techniques.

# %%
# Why Python?
# --- Popular language for data analysis, data science, and general programming
# --- Helps to create reproducible workflows to make research and analysis more efficient (modularize code, big data, etc.)

# Why Colab?
# --- Colab is cloud-based python notebook
# --- Don't have to install any software
# --- Can easily collaborate and ensure everyone has same version

# %%
# Colab navigation

# Comments use pound sign

# '+Code' to add code cell

# Play button to run code

# '+ Text' adds markdown cell

# ctrl + / does multline comments

# to toggle off AI features, go to Settings, AI Assistance, and uncheck boxes

# %%
# Data Types
# numeric types: ints (integers), floats (decimals), strings (characters - "")
# sequence types: lists, tuples, dictionaries, sets
# other: booleans, None

# %%
# ints
# 1,2,3,4,5 -> numbers
#5

# floats -> decimals
# 5.0

# strings -> characters

# "5.0"

# lists

# ["four", "4", "5", 5.0, 5] # allow you to store multiple items in the same variable

# dicionaries

# {"one": 1, "two": 2.0, "3.0": 3} # allow you to store multiple items in "key": value pairs

# booleans -> represents logical values, either true or false
# True
# False
# True or False
# True and False
# True and True
# False and False

# Different data types have different behavior
# Different functions work on them, and values are accessed in different ways

# %%
# Variables
# variables are names given to values
# the "=" assigns a value to a variable name
# variable names are case-sensitive and can't begin with a number

a = 5 # the number 5 is assigned to the variable name 'a'
a

# %%
b = 6
a+b

# %%
b = 5
b

# %%
a = b
a

# %%
a = "hi"
a

# %%
b = False
b

# %%
# Common Operators +, -, *, /, **, %, []
# some work differently on different data types

# ints
# a = 5
# a+2 # + allows you to add
# a-2 # - allows you to substract
# a +=1 # += allows you to increase by a number
# a
# a -= 1 # allows you to decrease by a number
# a
# a * 3
# a**3

# strings
# fst_word = "Hello"
# scd_word = "Goodbye"
# fst_word + scd_word # '+' sign allows you to concatenate strings
# fst_word + " " + scd_word
# fst_word += " " # allows you to add to a string
# fst_word
# fst_word += scd_word
# fst_word
# "And then they said \"Hello\"" # you can use a backslash/escape character
# to include quotations within a string
# fst_word * 2 # can repeat strings using the multiplication operator

# Indexing
# retrieving values from within a sequence data type is called "indexing"
# python "indexes" or starts counting at 0 instead of 1
# string = "That amiable youth, Jimmy Thesiger, came racing down the big staircase at Chimneys two steps at a time."
# string[0]
# string[-1]

# Slice
# slicing allows you to retrieve a portion or "slice"
# (inclusive start : exclusive end)
# string = "That amiable youth, Jimmy Thesiger, came racing down the big staircase at Chimneys two steps at a time."
# string[0:4]

# %%
# Lists
# my_list = ['That', 'amiable', 'youth,', 'Jimmy', 'Thesiger,', 'came', 'racing', 'down', 'the', 'big', 'staircase', 'at', 'Chimneys', 'two', 'steps', 'at', 'a', 'time.'] # can create with straight brackets
# my_list * 2 # repeat list elements using *

# # Indexing
# my_list[0] # first value
# my_list[-1] # last value

# # Slicing
# my_list[0:1]
# my_list[0:2]

# lst_one = my_list[0:6]
# lst_two = my_list[6:10]
# lst_one + lst_two # use + to add to different lists together
# lst_one += lst_two # add onto list using +=
# lst_one

# # Nesting lists
# [lst_one, lst_two]
# [lst_one, lst_two][0] # index into nested list by using square brackets
# [lst_one, lst_two][1] # first bracket indexes into the outer list and retrives the value at the index number
# # # in this case, it's a list
# [lst_one, lst_two][0][3] # since the first data type indexed is a list, you can index again using a second pair of brackets
# [lst_one, lst_two][0][3][0] # you can index a third time, since the next data type is a string, which also allows you to index

# %%
# Dictionaries - 33 mins
# book = {
#   "title": "The Seven Dials Mystery",
#   "author": "Agatha Christie",
#   "genres": ["mystery", "crime fiction", "thriller"],
#   "text": "That amiable youth, Jimmy Thesiger, came racing down the big staircase at Chimneys two steps at a time."
# } # create dictionary with curly brackets

# book["title"] # index into dictionary using square brackets and the name of the desired "key"
# book["genres"]
# book["genres"][0] # since the value of the key is a list, and lists support indexing, you can use second set of brackets to index into the

# %%
# Comparison Operators
# evaluate and then output a boolean value

# equal to
# a
# a==5
# not equal to
# a!=5
# greater than and less than
# b = 7
# a > b
# a < b

# %%
# Built-in Functions
# [function name](argument) -> think f(x) = y
# There are many built-in functions in Python
# You can also create your own function

# Help
# help(str)

# %%
# What data type is a?

# type(a)
# type(book["genres"][0])

# %%
# Print
# print() is a built-in Python function
# print() allows you to print objects to display a Python object in your output cell
# can print multiple variables/values at the same time, unlike just evaluating/running cell
# prints string without quotations

# print(a)
# print(5.0)
# print(type(a))
# print(type(5.0))

# %%
# More printing examples

# print(a)
# print('Exponent: ' + str(25**2))
# print('Multiplication: ' + str(25*2))
# print('Division: ' + str(25/2))

# %%
# Common built-in functions

# ints and floats
# max(1,10)
# min(1,10)
# pow(2,3)
# abs(-10.5)
# max(1, 3.5, 8)
# min(abs(-5), 1, 10)

# strings
# text = "Hello"
# len(text)
# text += " "
# text += "there"
# len(text)
# text
# text.find("Hello")
# text.find("bye")
# capital_text = text.upper()
# capital_text
# lower_text = text.lower()
# lower_text
# new_text = text.replace("Hello", "See")
# new_text
# text = " " + text
# text
# text.strip()
# text = text.strip()
# text.split(" ")

# %%
# lists

# len(my_list)
# lst_one.append("end")
# lst_one
# lst_one.extend(lst_two)
# lst_one
# my_list
# my_list.insert(0, "First Sentence:")
# my_list
# my_list.pop()
# my_list.reverse()
# my_list
# my_list.sort()
# my_list.sort(reverse=True)


# dictionaries
# book.keys()
# book.values()
# book.items()
# book.get("title")

# %%
# loops
# new_sent_length = 10
# print(lst_two)

# while len(lst_two) < new_sent_length:
#   lst_two.append("new word")
#   print(lst_two)

# # Using the range function for loops

# For Loops
# for word in lst_two:
#   print(word)
# for keys in book:
#   print(keys)
for values in book.values():
  print(values)
# for keys, values in book.items():
#   print(keys)
#   print(values)

# %%
# Flow Control
# if/elif/else

# a = "hello"
# b = "bye"

# if a == "hello":
#   print("The word is \"hello\"")
# else:
#   print("The word is not \"hello\"")

# if a != "hi":
#   print("Hi!")
# else:
#   print(b)

# %%
# Creating a function
# def print_element(lst):
#   for element in lst:
#     print(element)
#   return("Finished")

# print_element(my_list)

# %%
# loading standard libraries
# Python packages are collections of related functions typically targeted towards a specific topic.
# For example, the Pandas library contains a collection of functions related to data cleaning and analysis.
# Some packages are already available in Python and/or in colab, and some have to be installed

# !pip install -> to install
# import [library name] -> to import an installed package


# !pip install requests
# !pip install nltk

# import requests # allows us to make HTTP requests
# import nltk # a natural language processing library
# import json # allows us to work with JSON data

# %%
# APIs
# APIs are application programming interfaces. They are a set or rules and protocols that allow different software programs to interact and exchange information.
# APIs define how one application can request services or data from another.
# With many APIs, the workflow is that the "client" makes a request. In this case, our script is the client, and we are using our script to request book data.
# The API then takes the request, verifies its validity, and sends it to the server.
# The server processes our request and sends a response back via the API that is typically formatted in particular way. In this case, our response will be in JSON format.
# Requests usually specify an endpoint or url and a method. In this case, the endpoint we are using provides us with data about the specific book assigned to the provided book ID
# and the method we are using is "get"

# api = "http://gutendex.com/books/75288" # endpoint for the API
# seven_dials = requests.get(api).json() # request and method that result in response in JSON format

# seven_dials

# # access title
# seven_dials["title"]
# # index into authors dictionary and access name
# seven_dials["authors"][0]["name"]
# # access summaries and extract first sentence
# seven_dials["summaries"][0].split(".")[0]

# %%
# A note on file paths
# File paths provide the location of files or directories/folders.
# If you need to utilize any code files, images, data, etc. on your computer, you will need to tell Python where it is located

# Google colab file path
# /content
# to navigate to california housing training data ->
# /content/sample_data/california_housing_train.csv

# %%
# Text processing
# from google.colab import files

# book_txt = json.dumps(seven_dials) # create text file to write book data to

# with open("seven_dials.txt", "w") as f:
#   f.write(book_txt)


# # uploading files
# uploaded = files.upload()

# file_path = "/content/seven_dials.txt"

# Opening and reading in text

# with open(file_path, 'r') as f:
#     first_line = f.readline()
#     print(first_line)


# with open(file_path, "r") as f:
#     lines = f.readlines()[:5]
#     print(lines)


# summary = lines[0][150:718]


# Extracting text from pdf
# !pip install pypdf

# from pypdf import PdfReader

# uploaded = files.upload()
# file_path = "/content/seven_dials.pdf"


# with open("seven_dials.pdf", "rb") as file:
#     reader = PdfReader(file)

#     # Extract text from a specific page (e.g., the first page, index 0)
#     page = reader.pages[0]
#     text = page.extract_text()
#     print(text)

# %%
# Natural language processing

# import re # regular expression library

# cleaning text

# re.sub(r'[^\w\s]', '', summary)

# def clean_text(text):
#   clean = re.sub(r'[^\w\s]', '', text)
#   return clean

# clean = clean_text(text)
# clean = clean_text(summary)

# # case conversion

# # convert to lower case

# def lower_text(text):
#   lower = text.lower() # lower text
#   return lower

# clean = lower_text(clean)

# convert to upper case

# def upper_text(text):
#   upper = text.upper() # lower text
#   return upper

# clean = upper_text(clean)

# tokenization -> breaks down text data into smaller components (ie. sentences or words)

# a function for sentence tokenization
# def sent_tokenizer(text):
#     text = text.lower()
#     tokens = text.split(".")  # \w is a regular expression for any alphanumeric character
#     return tokens

# sent_tokenizer(clean)
# sent_tokens = sent_tokenizer(clean)
# print(sent_tokens)

# a function for word tokenization
# def word_tokenizer(text):
#     text = text.lower()
#     tokens = re.findall(r'\w+',text)  # \w is a regular expression for any alphanumeric character
#     return tokens

# word_tokenizer(clean)
# tokens = word_tokenizer(clean) # save tokens to variable

# print(tokens)

# %%
# Demo - using nltk library#
# nltk.download('punkt_tab') # for sentence and word tokenization

# tokens = nltk.sent_tokenize(text=summary)

# print(tokens)

# def clean_text(lst):
#   new_lst = []
#   for sent in lst:
#     new_sent = ""
#     for word in sent:
#       word = re.sub(r'[^a-zA-Z0-9\s]', '', word) # remove all punctuation from string
#       new_sent+= word.replace("\n", " ") # replace /n character with empty string
#     new_lst.append(new_sent)
#   return new_lst

# clean_tokens = clean_text(tokens)
# print(clean_tokens)
